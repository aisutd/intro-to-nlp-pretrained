# %% [markdown]
# # Word2Vec - Continuous Skip-gram Model

# %% [markdown]
# ## Import Libaries
#
#   - Import user defined corpus (text corpus, personal essays, etc.) using `wget`
#   - Import regex to process text
#   - Import Keras `Tokenizer`, padding, and text-to-word sequence

# %%
# !wget --no-check-certificate \
    https://raw.githubusercontent.com/aisutd/Intro-to-NLP-pretrained/main/word_embedding_models/data/sample_corpus_essay_Bach_Nguyen.txt \
    -O ./sample_corpus.txt

# !wget --no-check-certificate \
    https://raw.githubusercontent.com/aisutd/Intro-to-NLP-pretrained/main/word_embedding_models/data/shakespeare.txt \
    -O ./shakespeare.txt

# !wget --no-check-certificate \
    https://raw.githubusercontent.com/aisutd/Intro-to-NLP-pretrained/main/word_embedding_models/data/warpeace.txt \
    -O ./warpeace.txt
# Out:
# --2021-02-05 14:28:21--  https://raw.githubusercontent.com/aisutd/Intro-to-NLP-pretrained/main/word_embedding_models/data/sample_corpus_essay_Bach_Nguyen.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7406 (7.2K) [text/plain]
# Saving to: ‘./sample_corpus.txt’
#
# ./sample_corpus.txt 100%[===================>]   7.23K  --.-KB/s    in 0s
#
# 2021-02-05 14:28:21 (68.1 MB/s) - ‘./sample_corpus.txt’ saved [7406/7406]
#
# --2021-02-05 14:28:21--  https://raw.githubusercontent.com/aisutd/Intro-to-NLP-pretrained/main/word_embedding_models/data/shakespeare.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4573338 (4.4M) [text/plain]
# Saving to: ‘./shakespeare.txt’
#
# ./shakespeare.txt   100%[===================>]   4.36M  --.-KB/s    in 0.06s
#
# 2021-02-05 14:28:21 (77.9 MB/s) - ‘./shakespeare.txt’ saved [4573338/4573338]
#
# --2021-02-05 14:28:21--  https://raw.githubusercontent.com/aisutd/Intro-to-NLP-pretrained/main/word_embedding_models/data/warpeace.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3258246 (3.1M) [text/plain]
# Saving to: ‘./warpeace.txt’
#
# ./warpeace.txt      100%[===================>]   3.11M  --.-KB/s    in 0.06s
#
# 2021-02-05 14:28:22 (54.4 MB/s) - ‘./warpeace.txt’ saved [3258246/3258246]

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import io
import itertools
import numpy as np
import os
import re
import string
import tqdm
import datetime

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import text_to_word_sequence
from keras.preprocessing.sequence import skipgrams

import tensorflow as tf
from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Activation, Dense, Dot, Embedding, Flatten, Dense, GlobalAveragePooling1D, Reshape
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

# %%
SEED = 42
window_size = 2
num_ns = 4
AUTOTUNE = tf.data.AUTOTUNE

# %% [markdown]
# ## Preprocessing Text Data
#
#   - Split the training corpus into sentences
#   - Split all sentences in the training corpus into text sequence
#   - Tokenize to create a one-hot dictionary of all words in the corpus
#     - Note that more frequent words are tokenized by smaller numbers

# %%
#### Can we make the loading corpus process easier? My plan is to define a function that can:  
#### process: corpus--> parse --> sentence --> word_tokenize --> [ [word1,word2,word3...forming a sentence] , [word1,word2,word3...forming a sentence] ]
#### it uses nltk library
import nltk
import tensorflow as tf
nltk.download('punkt')

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import text_to_word_sequence

## determine the path of training corpus
corpus_path1 = 'warpeace.txt'
corpus_path2 = 'shakespeare.txt'
corpus_path3 = 'sample_corpus.txt'

## Aim: make the following transformations: 
## corpus--> parse --> sentence --> word_tokenize --> [ [word1,word2,word3...forming a sentence] , [word1,word2,word3...forming a sentence] ]
def load_corpus(corpus_path):
  f = open(corpus_path,encoding='utf-8-sig')
  content = f.read()
  ## in the warpeace.txt, there are two newline(Enter) characters between paragraphes, 
  ## so use .split('\n\n') to split paragraphs
  paragraphs = content.split('\n\n')
  sentences = []

  ## if you want to break a paragraph into sentences, could use:
  ## tokenize.sent_tokenize(paragraph) 
  ## it will break a sentence (str) into 
  ## a list of strings, each string is a sentence
  for i in paragraphs:
    sentences.extend(nltk.tokenize.sent_tokenize(i))
  
  words = []
  ## to break a sentence into words
  ## could use text_to_word_sequence(i)
  for i in sentences:
    temp = text_to_word_sequence(i)
    words.append(temp)
  
  return words

corpus = load_corpus(corpus_path1)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Use the Tokenizer to generate a one-hot dictionary
tokenizer = Tokenizer(oov_token='<OOV>')
tokenizer.fit_on_texts(corpus)
w2id = tokenizer.word_index
w2id['<pad>'] = 0
vocab_size = len(w2id)

id2w = {v:k for k, v in w2id.items()}

print(w2id)
print(id2w)
print("vocab_size: {}".format(vocab_size))
# Out:
# {'<OOV>': 1, 'the': 2, 'and': 3, 'to': 4, 'of': 5, 'a': 6, 'he': 7, 'in': 8, 'his': 9, 'that': 10, 'was': 11, 'with': 12, 'had': 13, 'it': 14, 'her': 15, 'not': 16, 'him': 17, 'at': 18, 'i': 19, 'but': 20, 'as': 21, 'on': 22, 'you': 23, 'for': 24, 'she': 25, 'is': 26, 'said': 27, 'all': 28, 'from': 29, 'be': 30, 'were': 31, 'by': 32, 'what': 33, 'they': 34, 'who': 35, 'this': 36, 'one': 37, 'which': 38, 'have': 39, 'so': 40, 'prince': 41, 'pierre': 42, 'an': 43, 'up': 44, 'them': 45, 'or': 46, 'when': 47, 'did': 48, 'been': 49, 'there': 50, 'their': 51, 'no': 52, 'would': 53, 'now': 54, 'only': 55, 'if': 56, 'me': 57, 'are': 58, 'out': 59, 'my': 60, 'could': 61, 'natasha': 62, 'man': 63, 'will': 64, 'more': 65, 'andrew': 66, 'do': 67, 'himself': 68, 'about': 69, 'into': 70, 'how': 71, 'we': 72, 'then': 73, 'time': 74, 'face': 75, 'french': 76, 'princess': 77, 'went': 78, 'some': 79, 'know': 80, 'after': 81, 'old': 82, 'before': 83, 'eyes': 84, 'your': 85, 'very': 86, 'men': 87, 'room': 88, 'thought': 89, 'like': 90, 'go': 91, 'well': 92, 'see': 93, 'rostov': 94, 'began': 95, 'moscow': 96, 'again': 97, 'has': 98, 'down': 99, 'came': 100, 'come': 101, 'still': 102, 'asked': 103, 'without': 104, 'same': 105, 'those': 106, 'army': 107, 'count': 108, 'looked': 109, 'say': 110, 'first': 111, 'felt': 112, 'our': 113, 'mary': 114, 'where': 115, 'away': 116, 'life': 117, 'left': 118, 'another': 119, 'nicholas': 120, 'something': 121, 'over': 122, 'two': 123, 'such': 124, 'these': 125, 'seemed': 126, 'other': 127, 'just': 128, 'its': 129, 'head': 130, 'yes': 131, 'little': 132, 'day': 133, 'long': 134, 'am': 135, 'why': 136, 'hand': 137, 'than': 138, 'whole': 139, 'people': 140, 'emperor': 141, "don't": 142, 'should': 143, 'back': 144, 'even': 145, 'own': 146, 'heard': 147, 'good': 148, 'having': 149, 'way': 150, 'because': 151, 'general': 152, 'napoleon': 153, 'here': 154, 'look': 155, 'must': 156, 'nothing': 157, 'can': 158, 'any': 159, 'always': 160, 'being': 161, 'saw': 162, 'made': 163, 'though': 164, 'love': 165, 'russian': 166, 'countess': 167, 'right': 168, 'kutuzov': 169, 'young': 170, 'suddenly': 171, 'round': 172, 'off': 173, 'voice': 174, 'us': 175, 'officer': 176, 'sonya': 177, 'smile': 178, 'moment': 179, 'looking': 180, 'everything': 181, 'knew': 182, 'never': 183, 'told': 184, 'whom': 185, 'while': 186, 'took': 187, 'house': 188, 'words': 189, 'much': 190, 'too': 191, 'turned': 192, 'dear': 193, 'let': 194, 'through': 195, 'quite': 196, "it's": 197, 'tell': 198, 'denisov': 199, 'under': 200, 'think': 201, 'get': 202, 'once': 203, 'battle': 204, 'take': 205, 'evidently': 206, 'understand': 207, 'yet': 208, 'last': 209, 'sat': 210, 'father': 211, 'soldiers': 212, 'every': 213, 'door': 214, 'herself': 215, 'most': 216, 'already': 217, 'feeling': 218, 'going': 219, 'oh': 220, 'might': 221, 'behind': 222, 'place': 223, 'stood': 224, 'gave': 225, 'done': 226, 'others': 227, 'replied': 228, 'expression': 229, 'side': 230, 'position': 231, 'war': 232, 'order': 233, 'anna': 234, 'toward': 235, 'anything': 236, "that's": 237, 'horse': 238, 'commander': 239, 'new': 240, 'seen': 241, 'dolokhov': 242, 'give': 243, 'may': 244, 'three': 245, 'boris': 246, 'make': 247, 'put': 248, 'also': 249, 'front': 250, 'ran': 251, 'god': 252, 'great': 253, 'hands': 254, 'troops': 255, 'both': 256, 'talk': 257, 'soon': 258, 'want': 259, 'wife': 260, 'petya': 261, 'shall': 262, 'petersburg': 263, 'called': 264, 'shouted': 265, 'taken': 266, 'alone': 267, 'between': 268, 'chief': 269, 'horses': 270, 'word': 271, 'whether': 272, 'part': 273, 'son': 274, 'many': 275, 'saying': 276, 'things': 277, 'thing': 278, 'letter': 279, 'along': 280, 'mind': 281, 'regiment': 282, 'table': 283, 'sent': 284, 'during': 285, 'rode': 286, 'against': 287, 'sitting': 288, 'night': 289, 'entered': 290, 'everyone': 291, 'found': 292, 'question': 293, 'officers': 294, 'evening': 295, 'moved': 296, 'among': 297, 'continued': 298, 'vasili': 299, 'speak': 300, 'drawing': 301, ' ...
# {1: '<OOV>', 2: 'the', 3: 'and', 4: 'to', 5: 'of', 6: 'a', 7: 'he', 8: 'in', 9: 'his', 10: 'that', 11: 'was', 12: 'with', 13: 'had', 14: 'it', 15: 'her', 16: 'not', 17: 'him', 18: 'at', 19: 'i', 20: 'but', 21: 'as', 22: 'on', 23: 'you', 24: 'for', 25: 'she', 26: 'is', 27: 'said', 28: 'all', 29: 'from', 30: 'be', 31: 'were', 32: 'by', 33: 'what', 34: 'they', 35: 'who', 36: 'this', 37: 'one', 38: 'which', 39: 'have', 40: 'so', 41: 'prince', 42: 'pierre', 43: 'an', 44: 'up', 45: 'them', 46: 'or', 47: 'when', 48: 'did', 49: 'been', 50: 'there', 51: 'their', 52: 'no', 53: 'would', 54: 'now', 55: 'only', 56: 'if', 57: 'me', 58: 'are', 59: 'out', 60: 'my', 61: 'could', 62: 'natasha', 63: 'man', 64: 'will', 65: 'more', 66: 'andrew', 67: 'do', 68: 'himself', 69: 'about', 70: 'into', 71: 'how', 72: 'we', 73: 'then', 74: 'time', 75: 'face', 76: 'french', 77: 'princess', 78: 'went', 79: 'some', 80: 'know', 81: 'after', 82: 'old', 83: 'before', 84: 'eyes', 85: 'your', 86: 'very', 87: 'men', 88: 'room', 89: 'thought', 90: 'like', 91: 'go', 92: 'well', 93: 'see', 94: 'rostov', 95: 'began', 96: 'moscow', 97: 'again', 98: 'has', 99: 'down', 100: 'came', 101: 'come', 102: 'still', 103: 'asked', 104: 'without', 105: 'same', 106: 'those', 107: 'army', 108: 'count', 109: 'looked', 110: 'say', 111: 'first', 112: 'felt', 113: 'our', 114: 'mary', 115: 'where', 116: 'away', 117: 'life', 118: 'left', 119: 'another', 120: 'nicholas', 121: 'something', 122: 'over', 123: 'two', 124: 'such', 125: 'these', 126: 'seemed', 127: 'other', 128: 'just', 129: 'its', 130: 'head', 131: 'yes', 132: 'little', 133: 'day', 134: 'long', 135: 'am', 136: 'why', 137: 'hand', 138: 'than', 139: 'whole', 140: 'people', 141: 'emperor', 142: "don't", 143: 'should', 144: 'back', 145: 'even', 146: 'own', 147: 'heard', 148: 'good', 149: 'having', 150: 'way', 151: 'because', 152: 'general', 153: 'napoleon', 154: 'here', 155: 'look', 156: 'must', 157: 'nothing', 158: 'can', 159: 'any', 160: 'always', 161: 'being', 162: 'saw', 163: 'made', 164: 'though', 165: 'love', 166: 'russian', 167: 'countess', 168: 'right', 169: 'kutuzov', 170: 'young', 171: 'suddenly', 172: 'round', 173: 'off', 174: 'voice', 175: 'us', 176: 'officer', 177: 'sonya', 178: 'smile', 179: 'moment', 180: 'looking', 181: 'everything', 182: 'knew', 183: 'never', 184: 'told', 185: 'whom', 186: 'while', 187: 'took', 188: 'house', 189: 'words', 190: 'much', 191: 'too', 192: 'turned', 193: 'dear', 194: 'let', 195: 'through', 196: 'quite', 197: "it's", 198: 'tell', 199: 'denisov', 200: 'under', 201: 'think', 202: 'get', 203: 'once', 204: 'battle', 205: 'take', 206: 'evidently', 207: 'understand', 208: 'yet', 209: 'last', 210: 'sat', 211: 'father', 212: 'soldiers', 213: 'every', 214: 'door', 215: 'herself', 216: 'most', 217: 'already', 218: 'feeling', 219: 'going', 220: 'oh', 221: 'might', 222: 'behind', 223: 'place', 224: 'stood', 225: 'gave', 226: 'done', 227: 'others', 228: 'replied', 229: 'expression', 230: 'side', 231: 'position', 232: 'war', 233: 'order', 234: 'anna', 235: 'toward', 236: 'anything', 237: "that's", 238: 'horse', 239: 'commander', 240: 'new', 241: 'seen', 242: 'dolokhov', 243: 'give', 244: 'may', 245: 'three', 246: 'boris', 247: 'make', 248: 'put', 249: 'also', 250: 'front', 251: 'ran', 252: 'god', 253: 'great', 254: 'hands', 255: 'troops', 256: 'both', 257: 'talk', 258: 'soon', 259: 'want', 260: 'wife', 261: 'petya', 262: 'shall', 263: 'petersburg', 264: 'called', 265: 'shouted', 266: 'taken', 267: 'alone', 268: 'between', 269: 'chief', 270: 'horses', 271: 'word', 272: 'whether', 273: 'part', 274: 'son', 275: 'many', 276: 'saying', 277: 'things', 278: 'thing', 279: 'letter', 280: 'along', 281: 'mind', 282: 'regiment', 283: 'table', 284: 'sent', 285: 'during', 286: 'rode', 287: 'against', 288: 'sitting', 289: 'night', 290: 'entered', 291: 'everyone', 292: 'found', 293: 'question', 294: 'officers', 295: 'evening', 296: 'moved', 297: 'among', 298: 'continued', 299: 'vasili', 300: 'speak', 301: 'drawing', 3 ...
# vocab_size: 18284

# %%
# Transform the corpus sequences into token sequences 
corpus_token_seq = [[w2id[word] for word in sentence] for sentence in corpus]

print(corpus_token_seq)
# Out:
# [[92, 41, 40, 7740, 3, 9283, 58, 54, 128, 457, 1444, 5, 2, 11973], [20, 19, 5359, 23, 56, 23, 142, 198, 57, 10, 36, 861, 232, 56, 23, 102, 852, 4, 2588, 2, 11974, 3, 4504, 7741, 32, 10, 5938, 19, 317, 514, 7, 26, 5938, 19, 64, 39, 157, 65, 4, 67, 12, 23, 3, 23, 58, 52, 362, 60, 381, 52, 362, 60, 11975, 3689, 322, 21, 23, 678, 550], [20, 71, 67, 23, 67], [19, 93, 19, 39, 551, 23, 881, 99, 3, 198, 57, 28, 2, 375], [14, 11, 8, 3305, 2323, 3, 2, 3127, 11, 2, 92, 426, 234, 569, 5360, 1016, 5, 410, 3, 1498, 5, 2, 2413, 562, 3306], [12, 125, 189, 25, 2825, 41, 299, 1017, 6, 63, 5, 499, 1769, 3, 1216, 35, 11, 2, 111, 4, 2324, 18, 15, 1185], [234, 569, 13, 13, 6, 4887, 24, 79, 350], [25, 11, 21, 25, 27, 827, 29, 1297, 9284, 9284, 161, 73, 6, 240, 271, 8, 1377, 263, 483, 55, 32, 2, 11976], [28, 15, 6689, 104, 2705, 950, 8, 76, 3, 3690, 32, 6, 6690, 7742, 1217, 10, 309, 251, 21, 2501], [56, 23, 39, 157, 393, 4, 67, 108, 46, 41, 3, 56, 2, 5361, 5, 3691, 43, 295, 12, 6, 802, 3307, 26, 16, 191, 407, 19, 262, 30, 86, 7743, 4, 93, 23, 3128, 268, 7744, 3, 6691, 3930, 5360], [4888], [33, 6, 9285, 600], [228, 2, 41, 16, 8, 2, 719, 3481, 32, 36, 1185], [7, 13, 128, 290, 882, 43, 4197, 862, 656, 1770, 2502, 3, 2147, 3, 13, 2589, 22, 9, 1320, 3, 6, 1470, 229, 22, 9, 4505, 75], [7, 382, 8, 10, 3692, 76, 8, 38, 113, 11977, 16, 55, 382, 20, 89, 3, 12, 2, 1349, 6692, 5362, 1350, 4, 6, 63, 5, 1216, 35, 13, 770, 82, 8, 474, 3, 18, 862], [7, 78, 44, 4, 234, 569, 538, 15, 137, 4198, 4, 15, 9, 771, 5939, 3, 2069, 130, 3, 6693, 1819, 68, 22, 2, 828], [111, 5, 28, 193, 381, 198, 57, 71, 23, 58], [404, 85, 2590, 281, 18, 586, 27, 7, 104, 7745, 9, 427, 2325, 2, 2826, 3, 2503, 1527, 5, 38, 2504, 3, 145, 2326, 61, 30, 9286], [158, 37, 30, 92, 186, 827, 4889], [158, 37, 30, 710, 8, 413, 90, 125, 56, 37, 98, 159, 218], [27, 234, 569], [23, 58, 1820, 2, 139, 295, 19, 683], [3, 2, 3693, 18, 2, 1771, 5940], [702, 26, 4890], [19, 156, 248, 8, 43, 1412, 50, 27, 2, 41], [60, 495, 26, 394, 24, 57, 4, 205, 57, 50], [19, 89, 7746, 3693, 13, 49, 11978], [19, 2827, 28, 125, 9287, 3, 6694, 58, 1627, 7747], [56, 34, 13, 426, 10, 23, 335, 14, 2, 5941, 53, 39, 49, 248, 173, 27, 2, 41, 35, 90, 6, 1351, 44, 3308, 32, 467, 5, 1445, 27, 277, 7, 48, 16, 145, 344, 4, 30, 1413], [142, 11979], [92, 3, 33, 98, 49, 627, 69, 11980, 2591], [23, 80, 181], [33, 158, 37, 110, 69, 14], [228, 2, 41, 8, 6, 458, 4506, 427], [33, 98, 49, 627], [34, 39, 627, 10, 1821, 98, 5363, 9, 5942, 3, 19, 514, 10, 72, 58, 388, 4, 2327, 1822], [41, 299, 160, 382, 6695, 90, 43, 7748, 1298, 6, 11981, 273], [234, 569, 5360, 22, 2, 505, 736, 15, 1270, 572, 5943, 12, 1823, 3, 11982], [4, 30, 43, 11983, 13, 518, 15, 2009, 4891, 3, 478, 145, 47, 25, 48, 16, 479, 90, 14, 25, 379, 3931, 8, 233, 16, 4, 5364, 2, 4199, 5, 106, 35, 182, 15], [2, 5944, 178, 38, 164, 14, 48, 16, 5365, 15, 6696, 2231, 160, 1271, 172, 15, 563, 545, 21, 8, 6, 3129, 628, 6, 3482, 893, 5, 15, 1096, 5945, 38, 25, 647, 335, 359, 61, 359, 618, 14, 462, 4, 2505], [8, 2, 1561, 5, 6, 384, 22, 1628, 829, 234, 569, 1168, 59], [220, 142, 300, 4, 57, 5, 1867], [555, 19, 142, 207, 277, 20, 1867, 183, 98, 335, 3, 314, 16, 344, 24, 232], [25, 26, 4200, 175], [389, 267, 156, 1471, 1169], [113, 2010, 1035, 5366, 9, 499, 4891, 3, 64, 30, 528, 4, 14], [10, 26, 2, 37, 278, 19, 39, 1951, 8], [113, 148, 3, 2232, 1035, 98, 4, 2978, 2, 11984, 2148, 22, 1018, 3, 7, 26, 40, 3483, 3, 1952, 10, 252, 64, 16, 11985, 17], [7, 64, 2706, 9, 4891, 3, 3309, 2, 11986, 5, 2070, 38, 98, 518, 65, 407, 138, 429, 8, 2, 843, 5, 36, 6697, 3, 5367], [72, 267, 156, 7749, 2, 940, 5, 2, 128, 37], [185, 19, 323, 23, 158, 72, 9288, 22], [3310, 12, 15, 11987, 1186, 64, 16, 3, 390, 207, 2, 141, 2414, 9289, 5, 414], [25, 98, 1868, 4, 11988, 9290], [25, 351, 4, 396, 3, 102, 5946, 79, 1414, 4507, 8, 113, 853], [33, 439, 48, 6698, 202], [1187], [2, 1771, 39, 16, 326, 3, 390, 207, 2, 459, 9291, 5, 113, 141, 35, 1824, 157, 24, 68, 20, 55, 2828, 2, 148, 5, 2328], [3, 33, 39, 34, 1063], [157], [3, 33, 132 ...

# %%
# Elements of each training example are appended to these lists
targets, contexts, labels = [], [], []

# Build the sampling table for vocab_size tokens.
sampling_table = tf.keras.preprocessing.sequence.make_sampling_table(vocab_size)

# Iterate over all sentences in the dataset
for sequence in tqdm.tqdm(corpus_token_seq):

  # Generate positive skip-gram pairs for a sequence (sentence).
  positive_skip_grams, _ = tf.keras.preprocessing.sequence.skipgrams(
        sequence, 
        vocabulary_size=vocab_size,
        sampling_table=sampling_table,
        window_size=window_size,
        negative_samples=0)
  
  # Iterate over each positive skip-gram pair to produce training samples 
  # with positive context word and negative context samples 
  for target_word, context_word in positive_skip_grams: 
    context_class = tf.expand_dims(
        tf.constant([context_word], dtype="int64"), 1)
    negative_sampling_candidates, _, _ = tf.random.log_uniform_candidate_sampler(
        true_classes=context_class,
        num_true=1, 
        num_sampled=num_ns, 
        unique=True, 
        range_max=vocab_size, 
        seed=SEED, 
        name="negative_sampling")
    
    # Build context and label vectors for one target word 
    negative_sampling_candidates = tf.expand_dims(
        negative_sampling_candidates, 1)
    
    context = tf.concat([context_class, negative_sampling_candidates], 0)
    label = tf.constant([1] + [0]*num_ns, dtype="int64")

    # Append each element from the training example to global lists
    targets.append(target_word)
    contexts.append(context)
    labels.append(label)
# Out:
# 100%|██████████| 32639/32639 [02:54<00:00, 187.24it/s]

# %%
print(len(targets))
print(len(contexts))
print(len(labels))
# Out:
# 335055
# 335055
# 335055

# %%
# Configuring the dataset with tensorflow batched dataset API
BATCH_SIZE = 1024
dataset = tf.data.Dataset.from_tensor_slices(((targets, contexts), labels))
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
print(dataset)
# Out:
# <BatchDataset shapes: (((1024,), (1024, 5, 1)), (1024, 5)), types: ((tf.int32, tf.int64), tf.int64)>

# %%
# Subclass to define Word2Vec model
class Word2Vec(Model):

  def __init__(self, vocab_size, embedding_dim):
    '''
      Initialize the model. 

      Parameters
      ----------
      vocab_size: int 
        size of the input vocabulary
      embedding_dim: int
        size of the embeddings (the number of parameters)
    '''
    super(Word2Vec, self).__init__()
    # Target embedding layer variable
    self.target_embedding = Embedding(vocab_size,
                                      embedding_dim, 
                                      input_length=1,
                                      name='w2v_embedding')     
    # Context embedding layer variable 
    self.context_embedding = Embedding(vocab_size, 
                                       embedding_dim, 
                                       input_length=num_ns+1)    
    # Dot layer variable (compute product along the word vector dimension)
    self.dots = Dot(axes=(3,2))
    self.flatten = Flatten()

  def call(self, pair):
    '''
      Function calling the model.

      Parameters
      ----------
      pair: tf.dataset
        training data in pair feed to the model
    '''
    target, context = pair
    # Calculate target and context embedding vectors
    we = self.target_embedding(target)
    ce = self.context_embedding(context)
    # Calculate target and context embedding similarity with dot product 
    dots = self.dots([ce, we])
    return self.flatten(dots)

# %%
# Build the model 
embedding_dim = 128
word2vec = Word2Vec(vocab_size, embedding_dim)
word2vec.compile(optimizer=tf.keras.optimizers.Adam(),
                 loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                 metrics=['accuracy'])

# %%
# Define callback to log training statistics
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
# Train the model 
word2vec.fit(dataset, epochs=20, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 327/327 [==============================] - 13s 38ms/step - loss: 1.5997 - accuracy: 0.2609
# Epoch 2/20
# 327/327 [==============================] - 12s 38ms/step - loss: 1.4500 - accuracy: 0.4286
# Epoch 3/20
# 327/327 [==============================] - 12s 38ms/step - loss: 1.3112 - accuracy: 0.4849
# Epoch 4/20
# 327/327 [==============================] - 12s 37ms/step - loss: 1.1872 - accuracy: 0.5580
# Epoch 5/20
# 327/327 [==============================] - 12s 37ms/step - loss: 1.0680 - accuracy: 0.6259
# Epoch 6/20
# 327/327 [==============================] - 12s 37ms/step - loss: 0.9549 - accuracy: 0.6847
# Epoch 7/20
# 327/327 [==============================] - 12s 38ms/step - loss: 0.8500 - accuracy: 0.7324
# Epoch 8/20
# 327/327 [==============================] - 12s 38ms/step - loss: 0.7552 - accuracy: 0.7708
# Epoch 9/20
# 327/327 [==============================] - 12s 37ms/step - loss: 0.6713 - accuracy: 0.8022
# Epoch 10/20
# 327/327 [==============================] - 12s 37ms/step - loss: 0.5981 - accuracy: 0.8269
# Epoch 11/20
# 327/327 [==============================] - 12s 37ms/step - loss: 0.5350 - accuracy: 0.8474
# Epoch 12/20
# 327/327 [==============================] - 12s 38ms/step - loss: 0.4808 - accuracy: 0.8652
# Epoch 13/20
# 327/327 [==============================] - 12s 38ms/step - loss: 0.4344 - accuracy: 0.8801
# Epoch 14/20
# 327/327 [==============================] - 12s 38ms/step - loss: 0.3946 - accuracy: 0.8925
# Epoch 15/20
# 327/327 [==============================] - 12s 38ms/step - loss: 0.3603 - accuracy: 0.9034
# Epoch 16/20
# 327/327 [==============================] - 12s 38ms/step - loss: 0.3307 - accuracy: 0.9124
# Epoch 17/20
# 327/327 [==============================] - 12s 38ms/step - loss: 0.3049 - accuracy: 0.9197
# Epoch 18/20
# 327/327 [==============================] - 12s 37ms/step - loss: 0.2825 - accuracy: 0.9263
# Epoch 19/20
# 327/327 [==============================] - 12s 38ms/step - loss: 0.2629 - accuracy: 0.9312
# Epoch 20/20
# 327/327 [==============================] - 12s 38ms/step - loss: 0.2456 - accuracy: 0.9355

# %%
# view model summary
print(word2vec.summary())
# Out:
# Model: "word2_vec_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# w2v_embedding (Embedding)    multiple                  2340352
# _________________________________________________________________
# embedding_3 (Embedding)      multiple                  2340352
# _________________________________________________________________
# dot_3 (Dot)                  multiple                  0
# _________________________________________________________________
# flatten_3 (Flatten)          multiple                  0
# =================================================================
# Total params: 4,680,704
# Trainable params: 4,680,704
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Output training logs
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 196), started 3:03:12 ago. (Use '!kill 196' to kill it.)

# %%
# Get the weights from the model 
weights = word2vec.get_layer('w2v_embedding').get_weights()[0]

# %%
# Create and save the vectors and metadata files
out_v = io.open('vectors.tsv', 'w', encoding='utf-8')
out_m = io.open('metadata.tsv', 'w', encoding='utf-8')

for index in id2w: 
  if  index == 0: continue # Skip padding token
  vector = weights[index]
  out_v.write('\t'.join([str(x) for x in vector]) + "\n")
  out_m.write(id2w[index] + "\n")

out_v.close()
out_m.close()

# %%
# Download the embeddings
try:
  from google.colab import files
  files.download('vectors.tsv')
  files.download('metadata.tsv')
except Exception as e:
  pass

# %%
# TODOS: 
# [DONE] Create context word vectors for training and label vectors (since the task is prediction)
# [DONE] Build a neural net with softmax to find the distribution of the most likely context word 
# Train the network for the neural task and extract the hidden layer weights as embeddings
# Sample by feeding the model a word to predict a context word of it
